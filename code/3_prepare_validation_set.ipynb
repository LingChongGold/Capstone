# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, silhouette_score
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.tree import DecisionTreeClassifier

# %%
full_df = pd.read_csv('../dataset/cleaned/combined_cleansed.csv')

# %% [markdown]
# ## Get Validation Set

# %%
train_ordered_products = pd.read_csv('../dataset/order_products__train.csv')
orders = pd.read_csv('../dataset/orders.csv')
products = pd.read_csv('../dataset/products.csv')

# %%
orders = orders[orders['eval_set'] == 'train']

# %%
validation_set = pd.merge(orders, train_ordered_products, how = 'left', on = 'order_id')
validation_set = pd.merge(validation_set, products, how = 'left', on = 'product_id')

# %%
validation_set.to_csv('../dataset/cleaned/validation.csv')

# %% [raw]
# validation_set.isnull().sum()

# %%
a = list(validation_set['user_id'].unique())

# %%
b = list(full_df['user_id'].unique())

# %% [raw]
# list(set(a) - set(b))

# %% [raw]
# list(set(b) - set(a))

# %% [markdown]
# ## Groupby

# %%
collaborative_df = full_df.groupby(['user_id', 'product_name', 'product_id'])['product_id'].agg('count').to_frame('purchase_count').reset_index()

# %%
collaborative_df[collaborative_df['user_id'] == 8]
# Out:
#      user_id                                product_name  product_id  \
# 273        8                               Bag of Lemons        6473
# 274        8                     Baked Beans, Vegetarian       33640
# 275        8                              Blueberry Pint       15143
# 276        8                                  Cane Sugar       49533
# 277        8                                     Carrots       17794
# 278        8                   Extra Sharp White Cheddar       32030
# 279        8                                      Garlic       34358
# 280        8                                 Green Beans       14992
# 281        8              Italian Extra Virgin Olive Oil       10644
# 282        8                       Low Sodium Beef Broth        6141
# 283        8                       Michigan Organic Kale       28985
# 284        8                        Organic Baby Spinach       21903
# 285        8                            Organic Broccoli        9839
# 286        8                         Organic Celery Root       32197
# 287        8                       Organic Coconut Cream       34190
# 288        8             Organic Dried Porcini Mushrooms       44099
# 289        8                Organic Heavy Whipping Cream       18531
# 290        8                                Organic Leek       23165
# 291        8    Organic Low Sodium Chicken Cooking Stock       11136
# 292        8          Organic Low Sodium Vegetable Broth       18479
# 293        8                Organic Premium Tomato Paste       23400
# 294        8                       Organic Salted Butter         651
# 295        8                               Organic Thyme       39812
# 296        8               Organic Whole White Mushrooms       41540
# 297        8                                Organic Yams       16349
# 298        8  Parsley, Italian (Flat), New England Grown        1529
# 299        8                            Red Chili Flakes       39110
# 300        8                               Russet Potato        8193
# 301        8                             Russet Potatoes       26882
# 302        8                                        Sage       20920
# 303        8                                     Shallot       15937
# 304        8                           Shredded Parmesan        4799
# 305        8                             Unsalted Butter       42736
# 306        8                  Unsalted Pure Irish Butter        2078
# 307        8                      Unsweetened Almondmilk       24838
# 308        8             Unsweetened Vanilla Almond Milk       43295
#
#      purchase_count
# 273               1
# 274               1
# 275               1
# 276               1
# 277               3
# 278               2
# 279               2
# 280               2
# 281               1
# 282               1
# 283               2
# 284               2
# 285               2
# 286               1
# 287               1
# 288               1
# 289               2
# 290               3
# 291               1
# 292               1
# 293               1
# 294               1
# 295               1
# 296               1
# 297               1
# 298               1
# 299               1
# 300               1
# 301               1
# 302               1
# 303               1
# 304               1
# 305               1
# 306               3
# 307               1
# 308               1

# %%
user_group = full_df.groupby('user_id')

# %%
# get first entry of the groups

user_group.first()
# Out:
#          order_id eval_set  order_number  order_dow  order_hour_of_day  \
# user_id
# 1         2539329    prior             1          2                  8
# 2         2168274    prior             1          2                 11
# 3         1374495    prior             1          1                 14
# 4         3343014    prior             1          6                 11
# 5         2717275    prior             1          3                 12
# ...           ...      ...           ...        ...                ...
# 206205     969311    prior             1          4                 12
# 206206    3189322    prior             1          3                 18
# 206207    2166133    prior             1          6                 19
# 206208    2227043    prior             1          1                 15
# 206209    3154581    prior             1          3                 11
#
#          days_since_prior_order  product_id  add_to_cart_order  reordered  \
# user_id
# 1                          15.0         196                  1          0
# 2                          10.0       32792                  1          0
# 3                           9.0        9387                  1          0
# 4                          19.0       36606                  1          0
# 5                          11.0       15349                  1          0
# ...                         ...         ...                ...        ...
# 206205                     30.0       27845                  1          0
# 206206                      3.0       13817                  1          0
# 206207                      1.0       47766                  1          0
# 206208                      8.0       34213                  1          0
# 206209                      7.0        6846                  1          0
#
#                                               product_name  aisle_id  \
# user_id
# 1                                                     Soda        77
# 2                           Chipotle Beef & Pork Realstick        23
# 3                                      Granny Smith Apples        24
# 4                               Sprouted Multi-Grain Bread       112
# 5                                 Organic Raw Agave Nectar        29
# ...                                                    ...       ...
# 206205                                  Organic Whole Milk        84
# 206206   \"Im Pei-nut Butter\" Double Chocolate Cookie ...        37
# 206207                                     Organic Avocado        24
# 206208                                   Great White Bread       112
# 206209                                     Diet Pepsi Pack        77
#
#          department_id  department                  aisle
# user_id
# 1                    7   beverages            soft drinks
# 2                   19      snacks          popcorn jerky
# 3                    4     produce           fresh fruits
# 4                    3      bakery                  bread
# 5                   13      pantry  honeys syrups nectars
# ...                ...         ...                    ...
# 206205              16  dairy eggs                   milk
# 206206               1      frozen          ice cream ice
# 206207               4     produce           fresh fruits
# 206208               3      bakery                  bread
# 206209               7   beverages            soft drinks
#
# [206209 rows x 14 columns]

# %%
# get everything from user 1

user_group.get_group(1)
# Out:
#     order_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329    prior             1          2                  8
# 1    2539329    prior             1          2                  8
# 2    2539329    prior             1          2                  8
# 3    2539329    prior             1          2                  8
# 4    2539329    prior             1          2                  8
# 5    2398795    prior             2          3                  7
# 6    2398795    prior             2          3                  7
# 7    2398795    prior             2          3                  7
# 8    2398795    prior             2          3                  7
# 9    2398795    prior             2          3                  7
# 10   2398795    prior             2          3                  7
# 11    473747    prior             3          3                 12
# 12    473747    prior             3          3                 12
# 13    473747    prior             3          3                 12
# 14    473747    prior             3          3                 12
# 15    473747    prior             3          3                 12
# 16   2254736    prior             4          4                  7
# 17   2254736    prior             4          4                  7
# 18   2254736    prior             4          4                  7
# 19   2254736    prior             4          4                  7
# 20   2254736    prior             4          4                  7
# 21    431534    prior             5          4                 15
# 22    431534    prior             5          4                 15
# 23    431534    prior             5          4                 15
# 24    431534    prior             5          4                 15
# 25    431534    prior             5          4                 15
# 26    431534    prior             5          4                 15
# 27    431534    prior             5          4                 15
# 28    431534    prior             5          4                 15
# 29   3367565    prior             6          2                  7
# 30   3367565    prior             6          2                  7
# 31   3367565    prior             6          2                  7
# 32   3367565    prior             6          2                  7
# 33    550135    prior             7          1                  9
# 34    550135    prior             7          1                  9
# 35    550135    prior             7          1                  9
# 36    550135    prior             7          1                  9
# 37    550135    prior             7          1                  9
# 38   3108588    prior             8          1                 14
# 39   3108588    prior             8          1                 14
# 40   3108588    prior             8          1                 14
# 41   3108588    prior             8          1                 14
# 42   3108588    prior             8          1                 14
# 43   3108588    prior             8          1                 14
# 44   2295261    prior             9          1                 16
# 45   2295261    prior             9          1                 16
# 46   2295261    prior             9          1                 16
# 47   2295261    prior             9          1                 16
# 48   2295261    prior             9          1                 16
# 49   2295261    prior             9          1                 16
# 50   2550362    prior            10          4                  8
# 51   2550362    prior            10          4                  8
# 52   2550362    prior            10          4                  8
# 53   2550362    prior            10          4                  8
# 54   2550362    prior            10          4                  8
# 55   2550362    prior            10          4                  8
# 56   2550362    prior            10          4                  8
# 57   2550362    prior            10          4                  8
# 58   2550362    prior            10          4                  8
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                      NaN       14084                  2          0
# 2                      NaN       12427                  3          0
# 3                      NaN       26088                  4          0
# 4                      NaN       26405                  5          0
# 5                     15.0         196                  1          1
# 6                     15.0       10258                  2          0
# 7                     15.0       12427                  3          1
# 8                     15.0       13176                  4          0
# 9                     15.0       26088                  5          1
# 10                    15.0       13032                  6          0
# 11                    21.0         196                  1          1
# 12                    21.0       12427                  2          1
# 13                    21.0       10258                  3          1
# 14                    21.0       25133                  4          0
# 15                    21.0       30450                  5          0
# 16                    29.0         196                  1          1
# 17                    29.0       12427                  2          1
# 18                    29.0       10258                  3          1
# 19                    29.0       25133                  4          1
# 20                    29.0       26405                  5          1
# 21                    28.0         196                  1          1
# 22                    28.0       12427                  2          1
# 23                    28.0       10258                  3          1
# 24                    28.0       25133                  4          1
# 25                    28.0       10326                  5          0
# 26                    28.0       17122                  6          0
# 27                    28.0       41787                  7          0
# 28                    28.0       13176                  8          1
# 29                    19.0         196                  1          1
# 30                    19.0       12427                  2          1
# 31                    19.0       10258                  3          1
# 32                    19.0       25133                  4          1
# 33                    20.0         196                  1          1
# 34                    20.0       10258                  2          1
# 35                    20.0       12427                  3          1
# 36                    20.0       25133                  4          1
# 37                    20.0       13032                  5          1
# 38                    14.0       12427                  1          1
# 39                    14.0         196                  2          1
# 40                    14.0       10258                  3          1
# 41                    14.0       25133                  4          1
# 42                    14.0       46149                  5          0
# 43                    14.0       49235                  6          0
# 44                     0.0       49235                  1          1
# 45                     0.0       46149                  2          1
# 46                     0.0       25133                  3          1
# 47                     0.0         196                  4          1
# 48                     0.0       10258                  5          1
# 49                     0.0       12427                  6          1
# 50                    30.0         196                  1          1
# 51                    30.0       46149                  2          1
# 52                    30.0       39657                  3          0
# 53                    30.0       38928                  4          0
# 54                    30.0       25133                  5          1
# 55                    30.0       10258                  6          1
# 56                    30.0       35951                  7          0
# 57                    30.0       13032                  8          1
# 58                    30.0       12427                  9          1
#
#                                product_name  aisle_id  department_id  \
# 0                                      Soda        77              7
# 1   Organic Unsweetened Vanilla Almond Milk        91             16
# 2                       Original Beef Jerky        23             19
# 3                Aged White Cheddar Popcorn        23             19
# 4          XL Pick-A-Size Paper Towel Rolls        54             17
# 5                                      Soda        77              7
# 6                                Pistachios       117             19
# 7                       Original Beef Jerky        23             19
# 8                    Bag of Organic Bananas        24              4
# 9                Aged White Cheddar Popcorn        23             19
# 10                    Cinnamon Toast Crunch       121             14
# 11                                     Soda        77              7
# 12                      Original Beef Jerky        23             19
# 13                               Pistachios       117             19
# 14                    Organic String Cheese        21             16
# 15                     Creamy Almond Butter        88             13
# 16                                     Soda        77              7
# 17                      Original Beef Jerky        23             19
# 18                               Pistachios       117             19
# 19                    Organic String Cheese        21             16
# 20         XL Pick-A-Size Paper Towel Rolls        54             17
# 21                                     Soda        77              7
# 22                      Original Beef Jerky        23             19
# 23                               Pistachios       117             19
# 24                    Organic String Cheese        21             16
# 25                      Organic Fuji Apples        24              4
# 26                        Honeycrisp Apples        24              4
# 27                           Bartlett Pears        24              4
# 28                   Bag of Organic Bananas        24              4
# 29                                     Soda        77              7
# 30                      Original Beef Jerky        23             19
# 31                               Pistachios       117             19
# 32                    Organic String Cheese        21             16
# 33                                     Soda        77              7
# 34                               Pistachios       117             19
# 35                      Original Beef Jerky        23             19
# 36                    Organic String Cheese        21             16
# 37                    Cinnamon Toast Crunch       121             14
# 38                      Original Beef Jerky        23             19
# 39                                     Soda        77              7
# 40                               Pistachios       117             19
# 41                    Organic String Cheese        21             16
# 42                        Zero Calorie Cola        77              7
# 43                      Organic Half & Half        53             16
# 44                      Organic Half & Half        53             16
# 45                        Zero Calorie Cola        77              7
# 46                    Organic String Cheese        21             16
# 47                                     Soda        77              7
# 48                               Pistachios       117             19
# 49                      Original Beef Jerky        23             19
# 50                                     Soda        77              7
# 51                        Zero Calorie Cola        77              7
# 52                   Milk Chocolate Almonds        45             19
# 53                 0% Greek Strained Yogurt       120             16
# 54                    Organic String Cheese        21             16
# 55                               Pistachios       117             19
# 56          Organic Unsweetened Almond Milk        91             16
# 57                    Cinnamon Toast Crunch       121             14
# 58                      Original Beef Jerky        23             19
#
#     department                   aisle
# 0    beverages             soft drinks
# 1   dairy eggs         soy lactosefree
# 2       snacks           popcorn jerky
# 3       snacks           popcorn jerky
# 4    household             paper goods
# 5    beverages             soft drinks
# 6       snacks  nuts seeds dried fruit
# 7       snacks           popcorn jerky
# 8      produce            fresh fruits
# 9       snacks           popcorn jerky
# 10   breakfast                  cereal
# 11   beverages             soft drinks
# 12      snacks           popcorn jerky
# 13      snacks  nuts seeds dried fruit
# 14  dairy eggs         packaged cheese
# 15      pantry                 spreads
# 16   beverages             soft drinks
# 17      snacks           popcorn jerky
# 18      snacks  nuts seeds dried fruit
# 19  dairy eggs         packaged cheese
# 20   household             paper goods
# 21   beverages             soft drinks
# 22      snacks           popcorn jerky
# 23      snacks  nuts seeds dried fruit
# 24  dairy eggs         packaged cheese
# 25     produce            fresh fruits
# 26     produce            fresh fruits
# 27     produce            fresh fruits
# 28     produce            fresh fruits
# 29   beverages             soft drinks
# 30      snacks           popcorn jerky
# 31      snacks  nuts seeds dried fruit
# 32  dairy eggs         packaged cheese
# 33   beverages             soft drinks
# 34      snacks  nuts seeds dried fruit
# 35      snacks           popcorn jerky
# 36  dairy eggs         packaged cheese
# 37   breakfast                  cereal
# 38      snacks           popcorn jerky
# 39   beverages             soft drinks
# 40      snacks  nuts seeds dried fruit
# 41  dairy eggs         packaged cheese
# 42   beverages             soft drinks
# 43  dairy eggs                   cream
# 44  dairy eggs                   cream
# 45   beverages             soft drinks
# 46  dairy eggs         packaged cheese
# 47   beverages             soft drinks
# 48      snacks  nuts seeds dried fruit
# 49      snacks           popcorn jerky
# 50   beverages             soft drinks
# 51   beverages             soft drinks
# 52      snacks         candy chocolate
# 53  dairy eggs                  yogurt
# 54  dairy eggs         packaged cheese
# 55      snacks  nuts seeds dried fruit
# 56  dairy eggs         soy lactosefree
# 57   breakfast                  cereal
# 58      snacks           popcorn jerky

# %%
test = full_df.groupby('user_id')['product_name']

# %%
test = pd.DataFrame(test, columns = ['user', 'product_bought'])

# %%
test.to_csv('test.csv')

# %%
test.head()
# Out:
#    0                                                  1
# 0  1  0                                        Soda
# ...
# 1  2  59               Chipotle Beef & Pork Realstic...
# 2  3  254                                Granny Smit...
# 3  4  342                           Sprouted Multi-G...
# 4  5  360                         Organic Raw Agave ...
